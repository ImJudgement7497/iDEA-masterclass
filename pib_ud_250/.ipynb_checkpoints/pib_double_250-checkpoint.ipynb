# %%
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display
import iDEA
import pickle

with open("energies_int_250.pkl", 'rb') as file:
    energies_int = pickle.load(file)

with open("energies_errors_250.pkl", 'rb') as file:
    energies_errors = pickle.load(file)

with open("energies_single_250.pkl", "rb") as file:
    energies_single = pickle.load(file)

with open("occupied_info_250.pkl", "rb") as file:
    occupied_info = pickle.load(file)

with open("occupied_levels_250.pkl", "rb") as file:
    occupied_levels = pickle.load(file)

# %%
for key, value in occupied_levels.items():
    print(f'{key}: {value}')
    print('---')
# Out:
# State = 0: ('Orbitals occupied by up: [0]', 'Orbitals occupied by down: [0]', 'Energy of occupied orbitals: [0.0197, 0.0197]', 'Total energy = 0.0394')
# ---
# State = 1: ('Orbitals occupied by up: [0]', 'Orbitals occupied by down: [1]', 'Energy of occupied orbitals: [0.0197, 0.0789]', 'Total energy = 0.0986')
# ---
# State = 2: ('Orbitals occupied by up: [1]', 'Orbitals occupied by down: [0]', 'Energy of occupied orbitals: [0.0789, 0.0197]', 'Total energy = 0.0986')
# ---
# State = 3: ('Orbitals occupied by up: [1]', 'Orbitals occupied by down: [1]', 'Energy of occupied orbitals: [0.0789, 0.0789]', 'Total energy = 0.1578')
# ---
# State = 4: ('Orbitals occupied by up: [0]', 'Orbitals occupied by down: [2]', 'Energy of occupied orbitals: [0.0197, 0.1775]', 'Total energy = 0.1972')
# ---
# State = 5: ('Orbitals occupied by up: [2]', 'Orbitals occupied by down: [0]', 'Energy of occupied orbitals: [0.1775, 0.0197]', 'Total energy = 0.1972')
# ---
# State = 6: ('Orbitals occupied by up: [1]', 'Orbitals occupied by down: [2]', 'Energy of occupied orbitals: [0.0789, 0.1775]', 'Total energy = 0.25639999999999996')
# ---
# State = 7: ('Orbitals occupied by up: [1]', 'Orbitals occupied by down: [2]', 'Energy of occupied orbitals: [0.0789, 0.1775]', 'Total energy = 0.25639999999999996')
# ---
# State = 8: ('Orbitals occupied by up: [0]', 'Orbitals occupied by down: [3]', 'Energy of occupied orbitals: [0.0197, 0.3155]', 'Total energy = 0.3352')
# ---
# State = 9: ('Orbitals occupied by up: [0]', 'Orbitals occupied by down: [3]', 'Energy of occupied orbitals: [0.0197, 0.3155]', 'Total energy = 0.3352')
# ---

# %%
# print results

print("Energies of interacting method 'ud'")
for i, value in enumerate(energies_int):
    print(f"State = {i}, energy = {value} per pi squared")
print("")
print("Energies of interacting method 'u'")
for i, value in enumerate(energies_single):
    print(f"State = {i}, energy = {value} per pi squared")
print("")
print("Errors")
for i, value in enumerate(energies_errors):
    print(f"State = {i}, error = {value} per pi squared")
# Out:
# Energies of interacting method 'ud'
# State = 0, energy = 0.0394 per pi squared
# State = 1, energy = 0.0986 per pi squared
# State = 2, energy = 0.0986 per pi squared
# State = 3, energy = 0.1577 per pi squared
# State = 4, energy = 0.1972 per pi squared
# State = 5, energy = 0.1972 per pi squared
# State = 6, energy = 0.2563 per pi squared
# State = 7, energy = 0.2563 per pi squared
# State = 8, energy = 0.3352 per pi squared
# State = 9, energy = 0.3352 per pi squared
#
# Energies of interacting method 'u'
# State = 0, energy = 0.0197 per pi squared
# State = 1, energy = 0.0789 per pi squared
# State = 2, energy = 0.1775 per pi squared
# State = 3, energy = 0.3155 per pi squared
# State = 4, energy = 0.4929 per pi squared
# State = 5, energy = 0.7098 per pi squared
# State = 6, energy = 0.9661 per pi squared
# State = 7, energy = 1.2619 per pi squared
# State = 8, energy = 1.5971 per pi squared
# State = 9, energy = 1.9717 per pi squared
#
# Errors
# State = 0, error = 12.4803 per pi squared
# State = 1, error = 49.9211 per pi squared
# State = 2, error = 112.3225 per pi squared
# State = 3, error = 199.6845 per pi squared
# State = 4, error = 312.0071 per pi squared
# State = 5, error = 449.2902 per pi squared
# State = 6, error = 611.5339 per pi squared
# State = 7, error = 798.7381 per pi squared
# State = 8, error = 1010.9029 per pi squared
# State = 9, error = 1248.0283 per pi squared

# %%
# print the degenerate states

for i in range(len(energies_int)):
    if energies_int[i] == energies_int[i-1]:
        print(f"State {i-1} and {i} have the same energy")
# Out:
# State 1 and 2 have the same energy
# State 4 and 5 have the same energy
# State 6 and 7 have the same energy
# State 8 and 9 have the same energy

# %%
# plot the energies

fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.set_xlim(0, 5)
ax2.set_xlim(0, 5)
for i, value in enumerate(energies_int):
    ax1.axhline(y=value, color='b', linestyle='-')
    if energies_int[i] == energies_int[i-1]:
        ax1.text(x=7, y=value, s=f'{value}', color='black', va='center', ha='right')
    else:
        ax1.text(x=7, y=value, s=f'{value}', color='red', va='center', ha='right')

for i, value in enumerate(energies_single):
    ax2.axhline(y=value, color='b', linestyle='-')
    ax2.text(x=7, y=value, s=f'{value}', color='red', va='center', ha='right')


ax1.set_title('Plot of energies from \n interacting method "ud"')
ax2.set_title('Plot of energies from \n interacting method "u"')
ax1.set_xlabel("Box")
ax1.set_ylabel("Energies")
ax2.set_xlabel("Box")
ax2.set_ylabel("Energies")
plt.tight_layout()
plt.show()

# %%
# occupied-info[state][0: up_occ_index, 1: down_occ_index, 2: orbital_energy, 3: energy_sum]

# Function to update the plot
def update_plot(k):
    plt.figure(figsize=(3, 4))
    plt.clf()

    # Plot horizontal lines and text for each value in energies_single
    for i, value in enumerate(energies_single):
        plt.axhline(y=value, color='b', linestyle='-')
        plt.text(x=(1.3), y=value, s=f'{value}', color='red', va='center', ha='right')
    
    if occupied_info[k][2][0] == occupied_info[k][2][1]:
        plt.plot(0.25, occupied_info[k][2][0], "ro")
        plt.plot(0.75, occupied_info[k][2][1], "go")
    else:
        plt.plot(0.5, occupied_info[k][2][0], "ro")
        plt.plot(0.5, occupied_info[k][2][1], "go")

    plt.xlim(0, 1)
    plt.ylim(min(energies_single) - 0.05 , max(energies_single) + 1)
    plt.title("k-state occupation, up=red, down=green")
    
    plt.show()

# Create a slider widget
k_slider = widgets.IntSlider(value=5, min=0, max=len(occupied_info) - 1, step=1, description='k:')

# Update the plot when the slider value changes
widgets.interact(update_plot, k=k_slider)

# Display the slider
display(k_slider)
# Out:
# interactive(children=(IntSlider(value=5, description='k:', max=9), Output()), _dom_classes=('widget-interact',…
# IntSlider(value=5, description='k:', max=9)
